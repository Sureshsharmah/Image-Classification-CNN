# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls                       # shows the location of folder
# Out:
# drive/  sample_data/

# %%
# !ls /content/drive/My\ Drive/
# Out:
#  Assesment.ipynb
#  Classroom
# 'Colab Notebooks'
# 'Copy of Copy of Excel Dashboard.xlsm'
# 'Copy of Excel Dashboard.xlsm'
# 'Data Scientist (1).pdf'
# 'Data Scientist (2).pdf'
# 'Data Scientist (3).pdf'
# 'Data Scientist (4).pdf'
# 'Data Scientist (5).pdf'
# 'Data Scientist (6).pdf'
# 'Data Scientist (7).pdf'
# 'Data Scientist CV (1).pdf'
# 'Data Scientist CV.pdf'
# 'Data Scientist.pdf'
# 'Family Update.gsite'
# 'Getting started.pdf'
#  IMG_20220115_151235.jpg
#  IMG_20220115_212733.jpg
#  IMG-20230206-WA0027.jpg
#  IMG-20230207-WA0004.jpeg
#  IMG-20230207-WA0008.jpeg
#  IMG_20230816_123121_951.jpg
#  Report.pdf
# 'Resume Suresh.pdf'
#  Screenshot_2023-09-12-12-09-42-929_com.whatsapp.jpg
#  Screenshot_2023-09-13-09-07-57-545_com.google.android.apps.nbu.paisa.user.jpg
#  Screenshot_2023-11-27-10-07-23-728_com.google.android.apps.nbu.paisa.user.jpg
#  Screenshot_2024-05-14-10-04-28-812_com.google.android.apps.nbu.paisa.user.jpg
# 'SQL TEST PAPER 2 ANSWER.pdf'
# ...

# %%
cd /content
# Out:
# /content

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
ls
# Out:
#  Assesment.ipynb
#  Classroom/
# 'Colab Notebooks'/
# 'Copy of Copy of Excel Dashboard.xlsm'
# 'Copy of Excel Dashboard.xlsm'
# 'Data Scientist (1).pdf'
# 'Data Scientist (2).pdf'
# 'Data Scientist (3).pdf'
# 'Data Scientist (4).pdf'
# 'Data Scientist (5).pdf'
# 'Data Scientist (6).pdf'
# 'Data Scientist (7).pdf'
# 'Data Scientist CV (1).pdf'
# 'Data Scientist CV.pdf'
# 'Data Scientist.pdf'
# 'Family Update.gsite'
# 'Getting started.pdf'
#  IMG_20220115_151235.jpg
#  IMG_20220115_212733.jpg
#  IMG-20230206-WA0027.jpg
#  IMG-20230207-WA0004.jpeg
#  IMG-20230207-WA0008.jpeg
#  IMG_20230816_123121_951.jpg
#  Report.pdf
# 'Resume Suresh.pdf'
#  Screenshot_2023-09-12-12-09-42-929_com.whatsapp.jpg
#  Screenshot_2023-09-13-09-07-57-545_com.google.android.apps.nbu.paisa.user.jpg
#  Screenshot_2023-11-27-10-07-23-728_com.google.android.apps.nbu.paisa.user.jpg
#  Screenshot_2024-05-14-10-04-28-812_com.google.android.apps.nbu.paisa.user.jpg
# 'SQL TEST PAPER 2 ANSWER.pdf'
# ...

# %%
cd yolo1
# Out:
# /content/drive/MyDrive/yolo1

# %%
ls
# Out:
# config.yaml  data/  runs/

# %%
# pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.2/881.2 kB 44.5 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.yaml')  # load a pretrained model (recommended for training)
model.train(data='/content/drive/MyDrive/yolo1/data/config.yaml',epochs=10)
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython import display
display.clear_output
# Out:
# <function IPython.core.display.clear_output(wait=False)>

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.28 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.4/112.6 GB disk)

# %%
from IPython.display import Image

# %%
Image(filename="runs/detect/train/confusion_matrix.png",width=600)

# %%
Image(filename="runs/detect/train/results.png",width=600)

# %%
Image(filename="runs/detect/train//val_batch0_labels.jpg",width=600)
